# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd ..
# Out:
# G:\Mes Documents\Documents\Python\Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass

# %%
cd ..
# Out:
# G:\Mes Documents\Documents\Python

# %%
cd Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass/
# Out:
# G:\Mes Documents\Documents\Python\Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass

# %%
cd Notes/
# Out:
# G:\Mes Documents\Documents\Python\Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass\Notes

# %%
cd 05-Seaborn/
# Out:
# G:\Mes Documents\Documents\Python\Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass\Notes\05-Seaborn

# %%
pwd
# Out:
# 'G:\\Mes Documents\\Documents\\Python\\Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass\\Notes\\05-Seaborn'

# %%
ccd ..
# Out:
#   File "<ipython-input-8-3b81a052d65a>", line 1
#     ccd ..
#          ^
# SyntaxError: invalid syntax

# %%
cd ../..
# Out:
# G:\Mes Documents\Documents\Python\Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass

# %%
cd Section07-Seaborn/
# Out:
# G:\Mes Documents\Documents\Python\Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass\Section07-Seaborn

# %%
filepath = 'G:\\Mes Documents\\Documents\\Python\\Udemy-Python-for-Machine-Learning-and-Data-Science-Masterclass\\Notes\\05-Seaborn'

# %%
df = pd.read_csv(filepath+'\\dm_office_sales.csv')

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(15,5),dpi=200)
sns.scatterplot(x='salary',y='sales',data=df,hue='training level',palette='plasma',s=200,alpha=0.4)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(15,5),dpi=200)
sns.scatterplot(x='salary',y='sales',data=df,size='salary')
plt.savefig('my_plot.jpg')
